# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
dataframe=pd.read_csv('housing.csv')

# %%
dataframe.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
dataframe.dropna
# Out:
# <bound method DataFrame.dropna of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
dataframe.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
dataframe.dropna(inplace=True)

# %% [markdown]
# ## Removing the null value rows from all the columns

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
#  ## Splitting the data into training and testing data

# %%
from sklearn.model_selection import train_test_split

x=dataframe.drop(['median_house_value'], axis=1)
y=dataframe['median_house_value']

# %%
x.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income ocean_proximity
# 0       322.0       126.0         8.3252        NEAR BAY
# 1      2401.0      1138.0         8.3014        NEAR BAY
# 2       496.0       177.0         7.2574        NEAR BAY
# 3       558.0       219.0         5.6431        NEAR BAY
# 4       565.0       259.0         3.8462        NEAR BAY

# %%
y.head()
# Out:
# 0    452600.0
# 1    358500.0
# 2    352100.0
# 3    341300.0
# 4    342200.0
# Name: median_house_value, dtype: float64

# %%
x_train , x_test , y_train , ytest =train_test_split(x,y ,test_size=0.2)

# %%
train_data=x_train.join(y_train)

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2693     -115.39     32.76                16.0       1136.0           196.0
# 1799     -122.37     37.93                37.0        709.0           190.0
# 55       -122.28     37.82                52.0        945.0           243.0
# 12789    -121.44     38.62                37.0       3009.0           733.0
# 5486     -118.46     33.98                27.0       2217.0           520.0
#
#        population  households  median_income ocean_proximity  \
# 2693        481.0       185.0         6.2558          INLAND
# 1799        644.0       174.0         0.8641        NEAR BAY
# 55          576.0       220.0         1.4113        NEAR BAY
# 12789      1513.0       588.0         1.4387          INLAND
# 5486        806.0       458.0         3.8935       <1H OCEAN
#
#        median_house_value
# 2693             146300.0
# 1799              84200.0
# 55                83100.0
# 12789             61000.0
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2693     -115.39     32.76                16.0       1136.0           196.0
# 1799     -122.37     37.93                37.0        709.0           190.0
# 55       -122.28     37.82                52.0        945.0           243.0
# 12789    -121.44     38.62                37.0       3009.0           733.0
# 5486     -118.46     33.98                27.0       2217.0           520.0
#
#        population  households  median_income ocean_proximity  \
# 2693        481.0       185.0         6.2558          INLAND
# 1799        644.0       174.0         0.8641        NEAR BAY
# 55          576.0       220.0         1.4113        NEAR BAY
# 12789      1513.0       588.0         1.4387          INLAND
# 5486        806.0       458.0         3.8935       <1H OCEAN
#
#        median_house_value
# 2693             146300.0
# 1799              84200.0
# 55                83100.0
# 12789             61000.0
# ...

# %%
# train_data.drop(['ocean_proximity'],axis=1, inplace=True)
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924420           -0.105700     0.044093
# latitude            -0.924420  1.000000            0.009043    -0.034982
# housing_median_age  -0.105700  0.009043            1.000000    -0.353203
# total_rooms          0.044093 -0.034982           -0.353203     1.000000
# total_bedrooms       0.069660 -0.065812           -0.315749     0.930546
# population           0.101402 -0.109873           -0.293469     0.859467
# households           0.056889 -0.071234           -0.298147     0.918622
# median_income       -0.018083 -0.079388           -0.113499     0.198545
# median_house_value  -0.041228 -0.148471            0.106368     0.135426
# <1H OCEAN            0.320902 -0.448358            0.044819    -0.003833
# INLAND              -0.056422  0.351880           -0.237819     0.026185
# ISLAND               0.008057 -0.014322            0.016922    -0.007876
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True )
# Out:
# <Axes: >

# %%
train_data['total_rooms']=np.log(train_data['total_rooms']+1)
train_data['total_bedrooms']=np.log(train_data['total_bedrooms']+1)
train_data['population']=np.log(train_data['population']+1)
train_data['households']=np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# train_data.ocean_proximity.value.count()

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude",y="longitude",data=train_data, hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2693     -115.39     32.76                16.0     7.036148        5.283204
# 1799     -122.37     37.93                37.0     6.565265        5.252273
# 55       -122.28     37.82                52.0     6.852243        5.497168
# 12789    -121.44     38.62                37.0     8.009695        6.598509
# 5486     -118.46     33.98                27.0     7.704361        6.255750
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 2693     6.177944    5.225747         6.2558            146300.0      False
# 1799     6.469250    5.164786         0.8641             84200.0      False
# 55       6.357842    5.398163         1.4113             83100.0      False
# 12789    7.322510    6.378426         1.4387             61000.0      False
# 5486     6.693324    6.129050         3.8935            500001.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# ...

# %% [markdown]
# ## Feature Engineering

# %%
train_data['bedroom_ratio']=train_data['total_bedrooms']/train_data['total_rooms']
train_data['household__rooms']=train_data['total_rooms']/train_data['households']
train_data['people_per_house']=train_data['population']/train_data['households']

# %%
train_data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2693     -115.39     32.76                16.0     7.036148        5.283204
# 1799     -122.37     37.93                37.0     6.565265        5.252273
# 55       -122.28     37.82                52.0     6.852243        5.497168
# 12789    -121.44     38.62                37.0     8.009695        6.598509
# 5486     -118.46     33.98                27.0     7.704361        6.255750
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 2693     6.177944    5.225747         6.2558            146300.0      False
# 1799     6.469250    5.164786         0.8641             84200.0      False
# 55       6.357842    5.398163         1.4113             83100.0      False
# 12789    7.322510    6.378426         1.4387             61000.0      False
# 5486     6.693324    6.129050         3.8935            500001.0       True
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

x_train , y_train=train_data.drop(['median_house_value'],axis=1),train_data['median_house_value']

reg=LinearRegression()

reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
test_data=x_test.join(ytest)

# %%
test_data['total_rooms']=np.log(test_data['total_rooms']+1)
test_data['total_bedrooms']=np.log(test_data['total_bedrooms']+1)
test_data['population']=np.log(test_data['population']+1)
test_data['households']=np.log(test_data['households']+1)

test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

test_data['bedroom_ratio']=test_data['total_bedrooms']/test_data['total_rooms']
test_data['household__rooms']=test_data['total_rooms']/test_data['households']
test_data['people_per_house']=test_data['population']/test_data['households']

# %%
x_test, ytest=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
ytest
# Out:
# 608      190800.0
# 6180     207000.0
# 18165    362200.0
# 4196     187100.0
# 12480    168800.0
#            ...
# 3578     275300.0
# 3731     237900.0
# 14915     98300.0
# 4749     259400.0
# 15960    266500.0
# Name: median_house_value, Length: 4087, dtype: float64

# %%
x_test, ytest=test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
x_train=train_data.drop(['median_house_value'],axis=1)

# %%
reg.score(x_test, ytest)
# Out:
# 0.6761067444661484

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

forest=RandomForestRegressor()
forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test,ytest)
# Out:
# 0.8144865835788845
